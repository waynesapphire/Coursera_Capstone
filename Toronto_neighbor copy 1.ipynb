# %% [markdown]
# # Segmenting and Clustering Neighborhoods in Toronto

# %% [markdown]
# ## This notebook is for capstone project for Coursera course.

# %% [markdown]
# ## Problem 1

# %%
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup

print("import sucess!")
# Out:
# import sucess!

# %%
wiki_url = 'https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'
source = requests.get(wiki_url).text
soup = BeautifulSoup(source, 'xml')
table = soup.find('table')
# table

# %%
# As requested: The dataframe will consist of three columns: PostalCode, Borough, and Neighborhood
columns_name = ['PostalCode','Borough','Neighborhood']
df = pd.DataFrame(columns = columns_name)
df
# Out:
# Empty DataFrame
# Columns: [PostalCode, Borough, Neighborhood]
# Index: []

# %%
# fill the data frame using the scraped data
for tr_cell in table.find_all('tr'):
    row_data=[]
    for td_cell in tr_cell.find_all('td'):
        row_data.append(td_cell.text.strip())
    if len(row_data)==3:
        df.loc[len(df)] = row_data
df.head()
# Out:
#   PostalCode           Borough               Neighborhood
# 0        M1A      Not assigned               Not assigned
# 1        M2A      Not assigned               Not assigned
# 2        M3A        North York                  Parkwoods
# 3        M4A        North York           Victoria Village
# 4        M5A  Downtown Toronto  Regent Park, Harbourfront

# %% [markdown]
# ## Remove those rows where "Borough" is "Not Assigned"

# %%
df = df[df['Borough']!='Not assigned']
df.head()
# Out:
#   PostalCode           Borough                                 Neighborhood
# 2        M3A        North York                                    Parkwoods
# 3        M4A        North York                             Victoria Village
# 4        M5A  Downtown Toronto                    Regent Park, Harbourfront
# 5        M6A        North York             Lawrence Manor, Lawrence Heights
# 6        M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government

# %%
df[df['Neighborhood']=='Not assigned']
df.head()
# Out:
#   PostalCode           Borough                                 Neighborhood
# 2        M3A        North York                                    Parkwoods
# 3        M4A        North York                             Victoria Village
# 4        M5A  Downtown Toronto                    Regent Park, Harbourfront
# 5        M6A        North York             Lawrence Manor, Lawrence Heights
# 6        M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government

# %%
temp_df=df.groupby('PostalCode')['Neighborhood'].apply(lambda x: "%s" % ', '.join(x))
temp_df=temp_df.reset_index(drop=False)
temp_df.rename(columns={'Neighborhood':'Neighborhood_joined'},inplace=True)

# %%
df_merge = pd.merge(df, temp_df, on='PostalCode')
df_merge.drop(['Neighborhood'], axis=1, inplace=True)
df_merge.drop_duplicates(inplace=True)
df_merge.rename(columns={'Neighborhood_joined':'Neighborhood'},inplace=True)

# %%
df_merge.head(20)
# Out:
#    PostalCode           Borough  \
# 0         M3A        North York
# 1         M4A        North York
# 2         M5A  Downtown Toronto
# 3         M6A        North York
# 4         M7A  Downtown Toronto
# 5         M9A         Etobicoke
# 6         M1B       Scarborough
# 7         M3B        North York
# 8         M4B         East York
# 9         M5B  Downtown Toronto
# 10        M6B        North York
# 11        M9B         Etobicoke
# 12        M1C       Scarborough
# 13        M3C        North York
# 14        M4C         East York
# 15        M5C  Downtown Toronto
# 16        M6C              York
# 17        M9C         Etobicoke
# 18        M1E       Scarborough
# 19        M4E      East Toronto
#
#                                          Neighborhood
# 0                                           Parkwoods
# 1                                    Victoria Village
# 2                           Regent Park, Harbourfront
# 3                    Lawrence Manor, Lawrence Heights
# ...

# %%
df_merge.shape
# Out:
# (103, 3)

# %% [markdown]
# ## Problem 2

# %% [markdown]
# ### Get geo information(coordinates)

# %%
def get_geo(postal_code):
    lat_lng = None
    while(lat_lng is None):
        g = geocoder.google('{}, Toronto,Ontario'.format(postal_code))
        lat_lng = g.latlng
    lat = lat_lng[0]
    lng = lat_lng[1]
    return lat, lng

# %%
geo_df=pd.read_csv('http://cocl.us/Geospatial_data')
geo_df.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %%
geo_df.rename(columns={'Postal Code':'PostalCode'},inplace=True)
geo_merged = pd.merge(geo_df, df_merge, on='PostalCode')
geo_data = geo_merged[['PostalCode','Borough','Neighbourhood','Latitude','Longitude']]
# geo_data.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-24-fe2d141c0203> in <module>
#       1 geo_df.rename(columns={'Postal Code':'PostalCode'},inplace=True)
#       2 geo_merged = pd.merge(geo_df, df_merge, on='PostalCode')
# ----> 3 geo_data = geo_merged[['PostalCode','Borough','Neighbourhood','Latitude','Longitude']]
#       4 # geo_data.head()
#
# /opt/conda/envs/Python36/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2932                 key = list(key)
#    2933             indexer = self.loc._convert_to_indexer(key, axis=1,
# -> 2934                                                    raise_missing=True)
#    2935
#    2936         # take() does not accept boolean indexers
#
# /opt/conda/envs/Python36/lib/python3.6/site-packages/pandas/core/indexing.py in _convert_to_indexer(self, obj, axis, is_setter, raise_missing)
# ...
